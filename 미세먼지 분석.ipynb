# %% [markdown]
# ## 목록

# %% [markdown]
# ### ***2021년***

# %%
import pandas as pd
data21_1= pd.read_excel("/content/drive/MyDrive/미세먼지 2001-21/2021년 1월.xlsx")
data21_1['지역']=data21_1['지역'].str[:2]
data21_1['측정일시'] = data21_1['측정일시'].astype(str)
data21_1['연도']=data21_1['측정일시'].str[:4]
data21_1['월']=data21_1['측정일시'].str[4:6]

data21_1=data21_1[['지역','측정소명','측정일시','PM10',	'PM25','연도','월']]
replace_set = {'PM10':data21_1['PM10'].mean()}
data21_1.fillna(replace_set, inplace=True)
replace_set = {'PM25':data21_1['PM25'].mean()}
data21_1.fillna(replace_set, inplace=True)
data21_1=data21_1.groupby(by=['지역','측정소명','연도','월'], as_index=False).mean()

# %%
data21_1

# %%
import pandas as pd
data21_2= pd.read_excel("/content/drive/MyDrive/미세먼지 2001-21/2021년 2월.xlsx")
data21_2['지역']=data21_2['지역'].str[:2]
data21_2['측정일시'] = data21_2['측정일시'].astype(str)
data21_2['연도']=data21_2['측정일시'].str[:4]
data21_2['월']=data21_2['측정일시'].str[4:6]

data21_2=data21_2[['지역','측정소명','PM10','PM25','연도','월']]

replace_set = {'PM10':data21_2['PM10'].mean()}
data21_2.fillna(replace_set, inplace=True)
replace_set = {'PM25':data21_2['PM25'].mean()}
data21_2.fillna(replace_set, inplace=True)
data21_2=data21_2.groupby(by=['지역','측정소명','연도','월'], as_index=False).mean()

# %%
import pandas as pd
data21_3= pd.read_excel("/content/drive/MyDrive/미세먼지 2001-21/2021년 3월.xlsx")
data21_3['지역']=data21_3['지역'].str[:2]
data21_3['측정일시'] = data21_3['측정일시'].astype(str)
data21_3['연도']=data21_3['측정일시'].str[:4]
data21_3['월']=data21_3['측정일시'].str[4:6]

data21_3=data21_3[['지역','측정소명','PM10','PM25','연도','월']]
replace_set = {'PM10':data21_3['PM10'].mean()}
data21_3.fillna(replace_set, inplace=True)
replace_set = {'PM25':data21_3['PM25'].mean()}
data21_3.fillna(replace_set, inplace=True)
data21_3=data21_3.groupby(by=['지역','측정소명','연도','월'], as_index=False).mean()

# %%
import pandas as pd
data21_4= pd.read_excel("/content/drive/MyDrive/미세먼지 2001-21/2021년 4월.xlsx")
data21_4['지역']=data21_4['지역'].str[:2]
data21_4['측정일시'] = data21_4['측정일시'].astype(str)
data21_4['연도']=data21_4['측정일시'].str[:4]
data21_4['월']=data21_4['측정일시'].str[4:6]

data21_4=data21_4[['지역','측정소명','PM10','PM25','연도','월']]
replace_set = {'PM10':data21_4['PM10'].mean()}
data21_4.fillna(replace_set, inplace=True)
replace_set = {'PM25':data21_4['PM25'].mean()}
data21_4.fillna(replace_set, inplace=True)
data21_4=data21_4.groupby(by=['지역','측정소명','연도','월'], as_index=False).mean()

# %%
data2021 = pd.concat([data21_1,data21_2,data21_3,data21_4],ignore_index=True)
data2021

# %% [markdown]
# ### ***2020년***

# %%
import pandas as pd
data20_1 = pd.read_excel("/content/drive/MyDrive/미세먼지 2001-21/2020년 1월.xlsx")
data20_1['지역']=data20_1['지역'].str[:2]
data20_1['측정일시'] = data20_1['측정일시'].astype(str)
replace_set = {'PM10':data20_1['PM10'].mean()}
data20_1.fillna(replace_set, inplace=True)
replace_set = {'PM25':data20_1['PM25'].mean()}
data20_1.fillna(replace_set, inplace=True)
data20_1['연도']=data20_1['측정일시'].str[:4]
data20_1['월']=data20_1['측정일시'].str[4:6]

data20_1=data20_1[['지역','측정소명','PM10','PM25','연도','월']]
data20_1=data20_1.groupby(by=['지역','측정소명','연도','월'], as_index=False).mean()

# %%
import pandas as pd
data20_2 = pd.read_excel("/content/drive/MyDrive/미세먼지 2001-21/2020년 2월.xlsx")
data20_2['지역']=data20_2['지역'].str[:2]
data20_2['측정일시'] = data20_2['측정일시'].astype(str)
replace_set = {'PM10':data20_2['PM10'].mean()}
data20_2.fillna(replace_set, inplace=True)
replace_set = {'PM25':data20_2['PM25'].mean()}
data20_2.fillna(replace_set, inplace=True)
data20_2['연도']=data20_2['측정일시'].str[:4]
data20_2['월']=data20_2['측정일시'].str[4:6]

data20_2=data20_2[['지역','측정소명','PM10','PM25','연도','월']]
data20_2=data20_2.groupby(by=['지역','측정소명','연도','월'], as_index=False).mean()

# %%
import pandas as pd
data20_3 = pd.read_excel("/content/drive/MyDrive/미세먼지 2001-21/2020년 3월.xlsx")
data20_3['지역']=data20_3['지역'].str[:2]
data20_3['측정일시'] = data20_3['측정일시'].astype(str)
replace_set = {'PM10':data20_3['PM10'].mean()}
data20_3.fillna(replace_set, inplace=True)
replace_set = {'PM25':data20_3['PM25'].mean()}
data20_3.fillna(replace_set, inplace=True)
data20_3['연도']=data20_3['측정일시'].str[:4]
data20_3['월']=data20_3['측정일시'].str[4:6]

data20_3=data20_3[['지역','측정소명','PM10','PM25','연도','월']]
data20_3=data20_3.groupby(by=['지역','측정소명','연도','월'], as_index=False).mean()

# %%
import pandas as pd
data20_4 = pd.read_excel("/content/drive/MyDrive/미세먼지 2001-21/2020년 4월.xlsx")
data20_4['지역']=data20_4['지역'].str[:2]
data20_4['측정일시'] = data20_4['측정일시'].astype(str)

replace_set = {'PM10':data20_4['PM10'].mean()}
data20_4.fillna(replace_set, inplace=True)
replace_set = {'PM25':data20_4['PM25'].mean()}
data20_4.fillna(replace_set, inplace=True)
data20_4['연도']=data20_4['측정일시'].str[:4]
data20_4['월']=data20_4['측정일시'].str[4:6]

data20_4=data20_4[['지역','측정소명','PM10','PM25','연도','월']]
data20_4=data20_4.groupby(by=['지역','측정소명','연도','월'], as_index=False).mean()

# %%
import pandas as pd
data20_5 = pd.read_excel("/content/drive/MyDrive/미세먼지 2001-21/2020년 5월.xlsx")
data20_5['지역']=data20_5['지역'].str[:2]
data20_5['측정일시'] = data20_5['측정일시'].astype(str)

replace_set = {'PM10':data20_5['PM10'].mean()}
data20_5.fillna(replace_set, inplace=True)
replace_set = {'PM25':data20_5['PM25'].mean()}
data20_5.fillna(replace_set, inplace=True)
data20_5['연도']=data20_5['측정일시'].str[:4]
data20_5['월']=data20_5['측정일시'].str[4:6]

data20_5=data20_5[['지역','측정소명','PM10','PM25','연도','월']]
data20_5=data20_5.groupby(by=['지역','측정소명','연도','월'], as_index=False).mean()

# %%
import pandas as pd
data20_6 = pd.read_excel("/content/drive/MyDrive/미세먼지 2001-21/2020년 6월.xlsx")
data20_6['지역']=data20_6['지역'].str[:2]
data20_6['측정일시'] = data20_6['측정일시'].astype(str)

replace_set = {'PM10':data20_6['PM10'].mean()}
data20_6.fillna(replace_set, inplace=True)
replace_set = {'PM25':data20_6['PM25'].mean()}
data20_6.fillna(replace_set, inplace=True)
data20_6['연도']=data20_6['측정일시'].str[:4]
data20_6['월']=data20_6['측정일시'].str[4:6]

data20_6=data20_6[['지역','측정소명','PM10','PM25','연도','월']]
data20_6=data20_6.groupby(by=['지역','측정소명','연도','월'], as_index=False).mean()

# %%
import pandas as pd
data20_7 = pd.read_excel("/content/drive/MyDrive/미세먼지 2001-21/2020년 7월.xlsx")
data20_7['지역']=data20_7['지역'].str[:2]
data20_7['측정일시'] = data20_7['측정일시'].astype(str)

replace_set = {'PM10':data20_7['PM10'].mean()}
data20_7.fillna(replace_set, inplace=True)
replace_set = {'PM25':data20_7['PM25'].mean()}
data20_7.fillna(replace_set, inplace=True)

data20_7['연도']=data20_7['측정일시'].str[:4]
data20_7['월']=data20_7['측정일시'].str[4:6]

data20_7=data20_7[['지역','측정소명','PM10','PM25','연도','월']]
data20_7=data20_7.groupby(by=['지역','측정소명','연도','월'], as_index=False).mean()

# %%
import pandas as pd
data20_8 = pd.read_excel("/content/drive/MyDrive/미세먼지 2001-21/2020년 8월.xlsx")
data20_8['지역']=data20_8['지역'].str[:2]
data20_8['측정일시'] = data20_8['측정일시'].astype(str)
replace_set = {'PM10':data20_8['PM10'].mean()}
data20_8.fillna(replace_set, inplace=True)
replace_set = {'PM25':data20_8['PM25'].mean()}
data20_8.fillna(replace_set, inplace=True)

data20_8['연도']=data20_8['측정일시'].str[:4]
data20_8['월']=data20_8['측정일시'].str[4:6]

data20_8=data20_8[['지역','측정소명','PM10','PM25','연도','월']]
data20_8=data20_8.groupby(by=['지역','측정소명','연도','월'], as_index=False).mean()

# %%
import pandas as pd
data20_9 = pd.read_excel("/content/drive/MyDrive/미세먼지 2001-21/2020년 9월.xlsx")
data20_9['지역']=data20_9['지역'].str[:2]
data20_9['측정일시'] = data20_9['측정일시'].astype(str)
replace_set = {'PM10':data20_9['PM10'].mean()}
data20_9.fillna(replace_set, inplace=True)
replace_set = {'PM25':data20_9['PM25'].mean()}
data20_9.fillna(replace_set, inplace=True)

data20_9['연도']=data20_9['측정일시'].str[:4]
data20_9['월']=data20_9['측정일시'].str[4:6]

data20_9=data20_9[['지역','측정소명','PM10','PM25','연도','월']]
data20_9=data20_9.groupby(by=['지역','측정소명','연도','월'], as_index=False).mean()

# %%
import pandas as pd
data20_10 = pd.read_excel("/content/drive/MyDrive/미세먼지 2001-21/2020년 10월.xlsx")
data20_10['지역']=data20_10['지역'].str[:2]
data20_10['측정일시'] = data20_10['측정일시'].astype(str)

replace_set = {'PM10':data20_10['PM10'].mean()}
data20_10.fillna(replace_set, inplace=True)
replace_set = {'PM25':data20_10['PM25'].mean()}
data20_10.fillna(replace_set, inplace=True)
data20_10['연도']=data20_10['측정일시'].str[:4]
data20_10['월']=data20_10['측정일시'].str[4:6]

data20_10=data20_10[['지역','측정소명','PM10','PM25','연도','월']]
data20_10=data20_10.groupby(by=['지역','측정소명','연도','월'], as_index=False).mean()

# %%
import pandas as pd
data20_11 = pd.read_excel("/content/drive/MyDrive/미세먼지 2001-21/2020년 11월.xlsx")
data20_11['지역']=data20_11['지역'].str[:2]
data20_11['측정일시'] = data20_11['측정일시'].astype(str)

replace_set = {'PM10':data20_11['PM10'].mean()}
data20_11.fillna(replace_set, inplace=True)
replace_set = {'PM25':data20_11['PM25'].mean()}
data20_11.fillna(replace_set, inplace=True)
data20_11['연도']=data20_11['측정일시'].str[:4]
data20_11['월']=data20_11['측정일시'].str[4:6]

data20_11=data20_11[['지역','측정소명','PM10','PM25','연도','월']]
data20_11=data20_11.groupby(by=['지역','측정소명','연도','월'], as_index=False).mean()

# %%
import pandas as pd
data20_12 = pd.read_excel("/content/drive/MyDrive/미세먼지 2001-21/2020년 12월.xlsx")
data20_12['지역']=data20_12['지역'].str[:2]
data20_12['측정일시'] = data20_12['측정일시'].astype(str)
data20_12['연도'] = data20_12['측정일시'].str[:4]
data20_12['월'] = data20_12['측정일시'].str[4:6]
replace_set = {'PM10':data20_12['PM10'].mean()}
data20_12.fillna(replace_set, inplace=True)
replace_set = {'PM25':data20_12['PM25'].mean()}
data20_12.fillna(replace_set, inplace=True)
data20_12['연도']=data20_12['측정일시'].str[:4]
data20_12['월']=data20_12['측정일시'].str[4:6]

data20_12=data20_12[['지역','측정소명','PM10','PM25','연도','월']]
data20_12=data20_12.groupby(by=['지역','측정소명','연도','월'], as_index=False).mean()

# %% [markdown]
# ### ***2019년***

# %%
import pandas as pd
data19_1 = pd.read_excel("/content/drive/MyDrive/미세먼지 2001-21/2019년 1월.xlsx")
data19_1['지역']=data19_1['지역'].str[:2]
data19_1['측정일시'] = data19_1['측정일시'].astype(str)

replace_set = {'PM10':data19_1['PM10'].mean()}
data19_1.fillna(replace_set, inplace=True)
replace_set = {'PM25':data19_1['PM25'].mean()}
data19_1.fillna(replace_set, inplace=True)

data19_1['연도']=data19_1['측정일시'].str[:4]
data19_1['월']=data19_1['측정일시'].str[4:6]

data19_1=data19_1[['지역','측정소명','PM10','PM25','연도','월']]
data19_1=data19_1.groupby(by=['지역','측정소명','연도','월'], as_index=False).mean()

# %%
import pandas as pd
data19_2 = pd.read_excel("/content/drive/MyDrive/미세먼지 2001-21/2019년 2월.xlsx")
data19_2['지역']=data19_2['지역'].str[:2]
data19_2['측정일시'] = data19_2['측정일시'].astype(str)
replace_set = {'PM10':data19_2['PM10'].mean()}
data19_2.fillna(replace_set, inplace=True)
replace_set = {'PM25':data19_2['PM25'].mean()}
data19_2.fillna(replace_set, inplace=True)

data19_2['연도']=data19_2['측정일시'].str[:4]
data19_2['월']=data19_2['측정일시'].str[4:6]

data19_2=data19_2[['지역','측정소명','PM10','PM25','연도','월']]
data19_2=data19_2.groupby(by=['지역','측정소명','연도','월'], as_index=False).mean()

# %%
import pandas as pd
data19_3 = pd.read_excel("/content/drive/MyDrive/미세먼지 2001-21/2019년 3월.xlsx")
data19_3['지역']=data19_3['지역'].str[:2]
data19_3['측정일시'] = data19_3['측정일시'].astype(str)
replace_set = {'PM10':data19_3['PM10'].mean()}
data19_3.fillna(replace_set, inplace=True)
replace_set = {'PM25':data19_3['PM25'].mean()}
data19_3.fillna(replace_set, inplace=True)

data19_3['연도']=data19_3['측정일시'].str[:4]
data19_3['월']=data19_3['측정일시'].str[4:6]

data19_3=data19_3[['지역','측정소명','PM10','PM25','연도','월']]
data19_3=data19_3.groupby(by=['지역','측정소명','연도','월'], as_index=False).mean()

# %%
import pandas as pd
data19_4 = pd.read_excel("/content/drive/MyDrive/미세먼지 2001-21/2019년 4월.xlsx")
data19_4['지역']=data19_4['지역'].str[:2]
data19_4['측정일시'] = data19_4['측정일시'].astype(str)
replace_set = {'PM10':data19_4['PM10'].mean()}
data19_4.fillna(replace_set, inplace=True)
replace_set = {'PM25':data19_4['PM25'].mean()}
data19_4.fillna(replace_set, inplace=True)

data19_4['연도']=data19_4['측정일시'].str[:4]
data19_4['월']=data19_4['측정일시'].str[4:6]

data19_4=data19_4[['지역','측정소명','PM10','PM25','연도','월']]
data19_4=data19_4.groupby(by=['지역','측정소명','연도','월'], as_index=False).mean()

# %%
import pandas as pd
data19_5 = pd.read_excel("/content/drive/MyDrive/미세먼지 2001-21/2019년 5월.xlsx")
data19_5['지역']=data19_5['지역'].str[:2]
data19_5['측정일시'] = data19_5['측정일시'].astype(str)

replace_set = {'PM10':data19_5['PM10'].mean()}
data19_5.fillna(replace_set, inplace=True)
replace_set = {'PM25':data19_5['PM25'].mean()}
data19_5.fillna(replace_set, inplace=True)

data19_5['연도']=data19_5['측정일시'].str[:4]
data19_5['월']=data19_5['측정일시'].str[4:6]

data19_5=data19_5[['지역','측정소명','PM10','PM25','연도','월']]
data19_5=data19_5.groupby(by=['지역','측정소명','연도','월'], as_index=False).mean()

# %%
import pandas as pd
data19_6 = pd.read_excel("/content/drive/MyDrive/미세먼지 2001-21/2019년 6월.xlsx")
data19_6['지역']=data19_6['지역'].str[:2]
data19_6['측정일시'] = data19_6['측정일시'].astype(str)

replace_set = {'PM10':data19_6['PM10'].mean()}
data19_6.fillna(replace_set, inplace=True)
replace_set = {'PM25':data19_6['PM25'].mean()}
data19_6.fillna(replace_set, inplace=True)

data19_6['연도']=data19_6['측정일시'].str[:4]
data19_6['월']=data19_6['측정일시'].str[4:6]

data19_6=data19_6[['지역','측정소명','PM10','PM25','연도','월']]
data19_6=data19_6.groupby(by=['지역','측정소명','연도','월'], as_index=False).mean()

# %%
import pandas as pd
data19_7 = pd.read_excel("/content/drive/MyDrive/미세먼지 2001-21/2019년 7월.xlsx")
data19_7['지역']=data19_7['지역'].str[:2]
data19_7['측정일시'] = data19_7['측정일시'].astype(str)
replace_set = {'PM10':data19_7['PM10'].mean()}
data19_7.fillna(replace_set, inplace=True)
replace_set = {'PM25':data19_7['PM25'].mean()}
data19_7.fillna(replace_set, inplace=True)

data19_7['연도']=data19_7['측정일시'].str[:4]
data19_7['월']=data19_7['측정일시'].str[4:6]

data19_7=data19_7[['지역','측정소명','PM10','PM25','연도','월']]
data19_7=data19_7.groupby(by=['지역','측정소명','연도','월'], as_index=False).mean()

# %%
import pandas as pd
data19_8 = pd.read_excel("/content/drive/MyDrive/미세먼지 2001-21/2019년 8월.xlsx")
data19_8['지역']=data19_8['지역'].str[:2]
data19_8['측정일시'] = data19_8['측정일시'].astype(str)

replace_set = {'PM10':data19_8['PM10'].mean()}
data19_8.fillna(replace_set, inplace=True)
replace_set = {'PM25':data19_8['PM25'].mean()}
data19_8.fillna(replace_set, inplace=True)

data19_8['연도']=data19_8['측정일시'].str[:4]
data19_8['월']=data19_8['측정일시'].str[4:6]

data19_8=data19_8[['지역','측정소명','PM10','PM25','연도','월']]
data19_8=data19_8.groupby(by=['지역','측정소명','연도','월'], as_index=False).mean()

# %%
import pandas as pd
data19_9 = pd.read_excel("/content/drive/MyDrive/미세먼지 2001-21/2019년 9월.xlsx")
data19_9['지역']=data19_9['지역'].str[:2]
data19_9['측정일시'] = data19_9['측정일시'].astype(str)

replace_set = {'PM10':data19_9['PM10'].mean()}
data19_9.fillna(replace_set, inplace=True)
replace_set = {'PM25':data19_9['PM25'].mean()}
data19_9.fillna(replace_set, inplace=True)

data19_9['연도']=data19_9['측정일시'].str[:4]
data19_9['월']=data19_9['측정일시'].str[4:6]

data19_9=data19_9[['지역','측정소명','PM10','PM25','연도','월']]
data19_9=data19_9.groupby(by=['지역','측정소명','연도','월'], as_index=False).mean()

# %%
import pandas as pd
data19_10 = pd.read_excel("/content/drive/MyDrive/미세먼지 2001-21/2019년 10월.xlsx")
data19_10['지역']=data19_10['지역'].str[:2]
data19_10['측정일시'] = data19_10['측정일시'].astype(str)

replace_set = {'PM10':data19_10['PM10'].mean()}
data19_10.fillna(replace_set, inplace=True)
replace_set = {'PM25':data19_10['PM25'].mean()}
data19_10.fillna(replace_set, inplace=True)

data19_10['연도']=data19_10['측정일시'].str[:4]
data19_10['월']=data19_10['측정일시'].str[4:6]

data19_10=data19_10[['지역','측정소명','PM10','PM25','연도','월']]
data19_10=data19_10.groupby(by=['지역','측정소명','연도','월'], as_index=False).mean()

# %%
import pandas as pd
data19_11 = pd.read_excel("/content/drive/MyDrive/미세먼지 2001-21/2019년 11월.xlsx")
data19_11['지역']=data19_11['지역'].str[:2]
data19_11['측정일시'] = data19_11['측정일시'].astype(str)

replace_set = {'PM10':data19_11['PM10'].mean()}
data19_11.fillna(replace_set, inplace=True)
replace_set = {'PM25':data19_11['PM25'].mean()}
data19_11.fillna(replace_set, inplace=True)

data19_11['연도']=data19_11['측정일시'].str[:4]
data19_11['월']=data19_11['측정일시'].str[4:6]

data19_11=data19_11[['지역','측정소명','PM10','PM25','연도','월']]
data19_11=data19_11.groupby(by=['지역','측정소명','연도','월'], as_index=False).mean()

# %%
import pandas as pd
data19_12 = pd.read_excel("/content/drive/MyDrive/미세먼지 2001-21/2019년 12월.xlsx")
data19_12['지역']=data19_12['지역'].str[:2]
data19_12['측정일시'] = data19_12['측정일시'].astype(str)

replace_set = {'PM10':data19_12['PM10'].mean()}
data19_12.fillna(replace_set, inplace=True)
replace_set = {'PM25':data19_12['PM25'].mean()}
data19_12.fillna(replace_set, inplace=True)

data19_12['연도']=data19_12['측정일시'].str[:4]
data19_12['월']=data19_12['측정일시'].str[4:6]

data19_12=data19_12[['지역','측정소명','PM10','PM25','연도','월']]
data19_12=data19_12.groupby(by=['지역','측정소명','연도','월'], as_index=False).mean()

# %% [markdown]
# ### ***2018년***

# %%
import pandas as pd
data18_b1 = pd.read_excel("/content/drive/MyDrive/미세먼지 2001-21/2018년 1분기.xlsx")
data18_b1['지역']=data18_b1['지역'].str[:2]
data18_b1['측정일시'] = data18_b1['측정일시'].astype(str)

replace_set = {'PM10':data18_b1['PM10'].mean()}
data18_b1.fillna(replace_set, inplace=True)
replace_set = {'PM25':data18_b1['PM25'].mean()}
data18_b1.fillna(replace_set, inplace=True)

data18_b1['연도']=data18_b1['측정일시'].str[:4]
data18_b1['월']=data18_b1['측정일시'].str[4:6]

data18_b1=data18_b1[['지역','측정소명','PM10','PM25','연도','월']]
data18_b1=data18_b1.groupby(by=['지역','측정소명','연도','월'], as_index=False).mean()

# %%
import pandas as pd
data18_b2 = pd.read_excel("/content/drive/MyDrive/미세먼지 2001-21/2018년 2분기.xlsx")
data18_b2['지역']=data18_b2['지역'].str[:2]
data18_b2['측정일시'] = data18_b2['측정일시'].astype(str)

replace_set = {'PM10':data18_b2['PM10'].mean()}
data18_b2.fillna(replace_set, inplace=True)
replace_set = {'PM25':data18_b2['PM25'].mean()}
data18_b2.fillna(replace_set, inplace=True)

data18_b2['연도']=data18_b2['측정일시'].str[:4]
data18_b2['월']=data18_b2['측정일시'].str[4:6]

data18_b2=data18_b2[['지역','측정소명','PM10','PM25','연도','월']]
data18_b2=data18_b2.groupby(by=['지역','측정소명','연도','월'], as_index=False).mean()

# %%
import pandas as pd
data18_b3 = pd.read_excel("/content/drive/MyDrive/미세먼지 2001-21/2018년 3분기.xlsx")
data18_b3['지역']=data18_b3['지역'].str[:2]
data18_b3['측정일시'] = data18_b3['측정일시'].astype(str)
replace_set = {'PM10':data18_b3['PM10'].mean()}
data18_b3.fillna(replace_set, inplace=True)
replace_set = {'PM25':data18_b3['PM25'].mean()}
data18_b3.fillna(replace_set, inplace=True)

data18_b3['연도']=data18_b3['측정일시'].str[:4]
data18_b3['월']=data18_b3['측정일시'].str[4:6]

data18_b3=data18_b3[['지역','측정소명','PM10','PM25','연도','월']]
data18_b3=data18_b3.groupby(by=['지역','측정소명','연도','월'], as_index=False).mean()

# %%
import pandas as pd
data18_b4 = pd.read_excel("/content/drive/MyDrive/미세먼지 2001-21/2018년 4분기.xlsx")
data18_b4['지역']=data18_b4['지역'].str[:2]
data18_b4['측정일시'] = data18_b4['측정일시'].astype(str)
replace_set = {'PM10':data18_b4['PM10'].mean()}
data18_b4.fillna(replace_set, inplace=True)
replace_set = {'PM25':data18_b4['PM25'].mean()}
data18_b4.fillna(replace_set, inplace=True)

data18_b4['연도']=data18_b4['측정일시'].str[:4]
data18_b4['월']=data18_b4['측정일시'].str[4:6]

data18_b4=data18_b4[['지역','측정소명','PM10','PM25','연도','월']]
data18_b4=data18_b4.groupby(by=['지역','측정소명','연도','월'], as_index=False).mean()

# %% [markdown]
# ### 2017년

# %%
import pandas as pd
data17_1 = pd.read_excel("/content/drive/MyDrive/미세먼지 2001-21/2017년 1월.xlsx")
data17_1['지역']=data17_1['지역'].str[:2]
data17_1['측정일시'] = data17_1['측정일시'].astype(str)

replace_set = {'PM10':data17_1['PM10'].mean()}
data17_1.fillna(replace_set, inplace=True)
replace_set = {'PM25':data17_1['PM25'].mean()}
data17_1.fillna(replace_set, inplace=True)

data17_1['연도']=data17_1['측정일시'].str[:4]
data17_1['월']=data17_1['측정일시'].str[4:6]

data17_1=data17_1[['지역','측정소명','PM10','PM25','연도','월']]
data17_1=data17_1.groupby(by=['지역','측정소명','연도','월'], as_index=False).mean()

# %%
import pandas as pd
data17_2 = pd.read_excel("/content/drive/MyDrive/미세먼지 2001-21/2017년 2월.xlsx")
data17_2['지역']=data17_2['지역'].str[:2]
data17_2['측정일시'] = data17_2['측정일시'].astype(str)
replace_set = {'PM10':data17_2['PM10'].mean()}
data17_2.fillna(replace_set, inplace=True)
replace_set = {'PM25':data17_2['PM25'].mean()}
data17_2.fillna(replace_set, inplace=True)

data17_2['연도']=data17_2['측정일시'].str[:4]
data17_2['월']=data17_2['측정일시'].str[4:6]

data17_2=data17_2[['지역','측정소명','PM10','PM25','연도','월']]
data17_2=data17_2.groupby(by=['지역','측정소명','연도','월'], as_index=False).mean()

# %%
import pandas as pd
data17_3 = pd.read_excel("/content/drive/MyDrive/미세먼지 2001-21/2017년 3월.xlsx")
data17_3['지역']=data17_3['지역'].str[:2]
data17_3['측정일시'] = data17_3['측정일시'].astype(str)
replace_set = {'PM10':data17_3['PM10'].mean()}
data17_3.fillna(replace_set, inplace=True)
replace_set = {'PM25':data17_3['PM25'].mean()}
data17_3.fillna(replace_set, inplace=True)

data17_3['연도']=data17_3['측정일시'].str[:4]
data17_3['월']=data17_3['측정일시'].str[4:6]

data17_3=data17_3[['지역','측정소명','PM10','PM25','연도','월']]
data17_3=data17_3.groupby(by=['지역','측정소명','연도','월'], as_index=False).mean()

# %%
import pandas as pd
data17_4 = pd.read_excel("/content/drive/MyDrive/미세먼지 2001-21/2017년 4월.xlsx")
data17_4['지역']=data17_4['지역'].str[:2]
data17_4['측정일시'] = data17_4['측정일시'].astype(str)
replace_set = {'PM10':data17_4['PM10'].mean()}
data17_4.fillna(replace_set, inplace=True)
replace_set = {'PM25':data17_4['PM25'].mean()}
data17_4.fillna(replace_set, inplace=True)

data17_4['연도']=data17_4['측정일시'].str[:4]
data17_4['월']=data17_4['측정일시'].str[4:6]

data17_4=data17_4[['지역','측정소명','PM10','PM25','연도','월']]
data17_4=data17_4.groupby(by=['지역','측정소명','연도','월'], as_index=False).mean()

# %%
import pandas as pd
data17_5 = pd.read_excel("/content/drive/MyDrive/미세먼지 2001-21/2017년 5월.xlsx")
data17_5['지역']=data17_5['지역'].str[:2]
data17_5['측정일시'] = data17_5['측정일시'].astype(str)
replace_set = {'PM10':data17_5['PM10'].mean()}
data17_5.fillna(replace_set, inplace=True)
replace_set = {'PM25':data17_5['PM25'].mean()}
data17_5.fillna(replace_set, inplace=True)

data17_5['연도']=data17_5['측정일시'].str[:4]
data17_5['월']=data17_5['측정일시'].str[4:6]

data17_5=data17_5[['지역','측정소명','PM10','PM25','연도','월']]
data17_5=data17_5.groupby(by=['지역','측정소명','연도','월'], as_index=False).mean()

# %%
import pandas as pd
data17_6 = pd.read_excel("/content/drive/MyDrive/미세먼지 2001-21/2017년 6월.xlsx")
data17_6['지역']=data17_6['지역'].str[:2]
data17_6['측정일시'] = data17_6['측정일시'].astype(str)
replace_set = {'PM10':data17_6['PM10'].mean()}
data17_6.fillna(replace_set, inplace=True)
replace_set = {'PM25':data17_6['PM25'].mean()}
data17_6.fillna(replace_set, inplace=True)

data17_6['연도']=data17_6['측정일시'].str[:4]
data17_6['월']=data17_6['측정일시'].str[4:6]

data17_6=data17_6[['지역','측정소명','PM10','PM25','연도','월']]
data17_6=data17_6.groupby(by=['지역','측정소명','연도','월'], as_index=False).mean()

# %%
import pandas as pd
data17_7 = pd.read_excel("/content/drive/MyDrive/미세먼지 2001-21/2017년 7월.xlsx")
data17_7['지역']=data17_7['지역'].str[:2]
data17_7['측정일시'] = data17_7['측정일시'].astype(str)
replace_set = {'PM10':data17_7['PM10'].mean()}
data17_7.fillna(replace_set, inplace=True)
replace_set = {'PM25':data17_7['PM25'].mean()}
data17_7.fillna(replace_set, inplace=True)

data17_7['연도']=data17_7['측정일시'].str[:4]
data17_7['월']=data17_7['측정일시'].str[4:6]

data17_7=data17_7[['지역','측정소명','PM10','PM25','연도','월']]
data17_7=data17_7.groupby(by=['지역','측정소명','연도','월'], as_index=False).mean()

# %%
import pandas as pd
data17_8 = pd.read_excel("/content/drive/MyDrive/미세먼지 2001-21/2017년 8월.xlsx")
data17_8['지역']=data17_8['지역'].str[:2]
data17_8['측정일시'] = data17_8['측정일시'].astype(str)
replace_set = {'PM10':data17_8['PM10'].mean()}
data17_8.fillna(replace_set, inplace=True)
replace_set = {'PM25':data17_8['PM25'].mean()}
data17_8.fillna(replace_set, inplace=True)

data17_8['연도']=data17_8['측정일시'].str[:4]
data17_8['월']=data17_8['측정일시'].str[4:6]

data17_8=data17_8[['지역','측정소명','PM10','PM25','연도','월']]
data17_8=data17_8.groupby(by=['지역','측정소명','연도','월'], as_index=False).mean()

# %%
import pandas as pd
data17_9 = pd.read_excel("/content/drive/MyDrive/미세먼지 2001-21/2017년 9월.xlsx")
data17_9['지역']=data17_9['지역'].str[:2]
data17_9['측정일시'] = data17_9['측정일시'].astype(str)
replace_set = {'PM10':data17_9['PM10'].mean()}
data17_9.fillna(replace_set, inplace=True)
replace_set = {'PM25':data17_9['PM25'].mean()}
data17_9.fillna(replace_set, inplace=True)

data17_9['연도']=data17_9['측정일시'].str[:4]
data17_9['월']=data17_9['측정일시'].str[4:6]

data17_9=data17_9[['지역','측정소명','PM10','PM25','연도','월']]
data17_9=data17_9.groupby(by=['지역','측정소명','연도','월'], as_index=False).mean()

# %%
import pandas as pd
data17_10 = pd.read_excel("/content/drive/MyDrive/미세먼지 2001-21/2017년 10월.xlsx")
data17_10['지역']=data17_10['지역'].str[:2]
data17_10['측정일시'] = data17_10['측정일시'].astype(str)
replace_set = {'PM10':data17_10['PM10'].mean()}
data17_10.fillna(replace_set, inplace=True)
replace_set = {'PM25':data17_10['PM25'].mean()}
data17_10.fillna(replace_set, inplace=True)

data17_10['연도']=data17_10['측정일시'].str[:4]
data17_10['월']=data17_10['측정일시'].str[4:6]

data17_10=data17_10[['지역','측정소명','PM10','PM25','연도','월']]
data17_10=data17_10.groupby(by=['지역','측정소명','연도','월'], as_index=False).mean()

# %%
import pandas as pd
data17_11 = pd.read_excel("/content/drive/MyDrive/미세먼지 2001-21/2017년 11월.xlsx")
data17_11['지역']=data17_11['지역'].str[:2]
data17_11['측정일시'] = data17_11['측정일시'].astype(str)
replace_set = {'PM10':data17_11['PM10'].mean()}
data17_11.fillna(replace_set, inplace=True)
replace_set = {'PM25':data17_11['PM25'].mean()}
data17_11.fillna(replace_set, inplace=True)

data17_11['연도']=data17_11['측정일시'].str[:4]
data17_11['월']=data17_11['측정일시'].str[4:6]

data17_11=data17_11[['지역','측정소명','PM10','PM25','연도','월']]
data17_11=data17_11.groupby(by=['지역','측정소명','연도','월'], as_index=False).mean()

# %%
import pandas as pd
data17_12 = pd.read_excel("/content/drive/MyDrive/미세먼지 2001-21/2017년 12월.xlsx")
data17_12['지역']=data17_12['지역'].str[:2]
data17_12['측정일시'] = data17_12['측정일시'].astype(str)
replace_set = {'PM10':data17_12['PM10'].mean()}
data17_12.fillna(replace_set, inplace=True)
replace_set = {'PM25':data17_12['PM25'].mean()}
data17_12.fillna(replace_set, inplace=True)

data17_12['연도']=data17_12['측정일시'].str[:4]
data17_12['월']=data17_12['측정일시'].str[4:6]

data17_12=data17_12[['지역','측정소명','PM10','PM25','연도','월']]
data17_12=data17_12.groupby(by=['지역','측정소명','연도','월'], as_index=False).mean()

# %% [markdown]
# ### 2016년

# %%
import pandas as pd
data16_b1 = pd.read_csv("/content/drive/MyDrive/미세먼지 2001-21/2016년 1분기.csv")
data16_b1['지역']=data16_b1['지역'].str[:2]
data16_b1['측정일시'] = data16_b1['측정일시'].astype(str)

replace_set = {'PM10':data16_b1['PM10'].mean()}
data16_b1.fillna(replace_set, inplace=True)
replace_set = {'PM25':data16_b1['PM25'].mean()}
data16_b1.fillna(replace_set, inplace=True)

data16_b1['연도']=data16_b1['측정일시'].str[:4]
data16_b1['월']=data16_b1['측정일시'].str[4:6]

data16_b1=data16_b1[['지역','측정소명','PM10','PM25','연도','월']]
data16_b1=data16_b1.groupby(by=['지역','측정소명','연도','월'], as_index=False).mean()

# %%
import pandas as pd
data16_b2 = pd.read_csv("/content/drive/MyDrive/미세먼지 2001-21/2016년 2분기.csv")
data16_b2['지역']=data16_b2['지역'].str[:2]
data16_b2['측정일시'] = data16_b2['측정일시'].astype(str)

replace_set = {'PM10':data16_b2['PM10'].mean()}
data16_b2.fillna(replace_set, inplace=True)
replace_set = {'PM25':data16_b2['PM25'].mean()}
data16_b2.fillna(replace_set, inplace=True)

data16_b2['연도']=data16_b2['측정일시'].str[:4]
data16_b2['월']=data16_b2['측정일시'].str[4:6]

data16_b2=data16_b2[['지역','측정소명','PM10','PM25','연도','월']]
data16_b2=data16_b2.groupby(by=['지역','측정소명','연도','월'], as_index=False).mean()

# %%
import pandas as pd
data16_b3 = pd.read_csv("/content/drive/MyDrive/미세먼지 2001-21/2016년 3분기.csv")
data16_b3['지역']=data16_b3['지역'].str[:2]
data16_b3['측정일시'] = data16_b3['측정일시'].astype(str)

replace_set = {'PM10':data16_b3['PM10'].mean()}
data16_b3.fillna(replace_set, inplace=True)
replace_set = {'PM25':data16_b3['PM25'].mean()}
data16_b3.fillna(replace_set, inplace=True)

data16_b3['연도']=data16_b3['측정일시'].str[:4]
data16_b3['월']=data16_b3['측정일시'].str[4:6]

data16_b3=data16_b3[['지역','측정소명','PM10','PM25','연도','월']]
data16_b3=data16_b3.groupby(by=['지역','측정소명','연도','월'], as_index=False).mean()

# %%
import pandas as pd
data16_b4 = pd.read_csv("/content/drive/MyDrive/미세먼지 2001-21/2016년 4분기.csv")
data16_b4['지역']=data16_b4['지역'].str[:2]
data16_b4['측정일시'] = data16_b4['측정일시'].astype(str)
replace_set = {'PM10':data16_b4['PM10'].mean()}
data16_b4.fillna(replace_set, inplace=True)
replace_set = {'PM25':data16_b4['PM25'].mean()}
data16_b4.fillna(replace_set, inplace=True)

data16_b4['연도']=data16_b4['측정일시'].str[:4]
data16_b4['월']=data16_b4['측정일시'].str[4:6]

data16_b4=data16_b4[['지역','측정소명','PM10','PM25','연도','월']]
data16_b4=data16_b4.groupby(by=['지역','측정소명','연도','월'], as_index=False).mean()

# %% [markdown]
# ### 2015년

# %%
import pandas as pd
data15_b1 = pd.read_csv("/content/drive/MyDrive/미세먼지 2001-21/2015년1분기.csv")
data15_b1['지역']=data15_b1['지역'].str[:2]
data15_b1['측정일시'] = data15_b1['측정일시'].astype(str)

replace_set = {'PM10':data15_b1['PM10'].mean()}
data15_b1.fillna(replace_set, inplace=True)

data15_b1['연도']=data15_b1['측정일시'].str[:4]
data15_b1['월']=data15_b1['측정일시'].str[4:6]

data15_b1=data15_b1[['지역','측정소명','PM10','연도','월']]
data15_b1=data15_b1.groupby(by=['지역','측정소명','연도','월'], as_index=False).mean()

# %%
import pandas as pd
data15_b2 = pd.read_csv("/content/drive/MyDrive/미세먼지 2001-21/2015년2분기.csv")
data15_b2['지역']=data15_b2['지역'].str[:2]
data15_b2['측정일시'] = data15_b2['측정일시'].astype(str)

replace_set = {'PM10':data15_b2['PM10'].mean()}
data15_b2.fillna(replace_set, inplace=True)

data15_b2['연도']=data15_b2['측정일시'].str[:4]
data15_b2['월']=data15_b2['측정일시'].str[4:6]

data15_b2=data15_b2[['지역','측정소명','PM10','연도','월']]
data15_b2=data15_b2.groupby(by=['지역','측정소명','연도','월'], as_index=False).mean()

# %%
import pandas as pd
data15_b3 = pd.read_csv("/content/drive/MyDrive/미세먼지 2001-21/2015년3분기.csv")
data15_b3['지역']=data15_b3['지역'].str[:2]
data15_b3['측정일시'] = data15_b3['측정일시'].astype(str)

replace_set = {'PM10':data15_b3['PM10'].mean()}
data15_b3.fillna(replace_set, inplace=True)

data15_b3['연도']=data15_b3['측정일시'].str[:4]
data15_b3['월']=data15_b3['측정일시'].str[4:6]

data15_b3=data15_b3[['지역','측정소명','PM10','연도','월']]
data15_b3=data15_b3.groupby(by=['지역','측정소명','연도','월'], as_index=False).mean()

# %%
import pandas as pd
data15_b4 = pd.read_csv("/content/drive/MyDrive/미세먼지 2001-21/2015년4분기.csv")
data15_b4['지역']=data15_b4['지역'].str[:2]
data15_b4['측정일시'] = data15_b4['측정일시'].astype(str)

replace_set = {'PM10':data15_b4['PM10'].mean()}
data15_b4.fillna(replace_set, inplace=True)

data15_b4['연도']=data15_b4['측정일시'].str[:4]
data15_b4['월']=data15_b4['측정일시'].str[4:6]

data15_b4=data15_b4[['지역','측정소명','PM10','연도','월']]
data15_b4=data15_b4.groupby(by=['지역','측정소명','연도','월'], as_index=False).mean()

# %% [markdown]
# ### 2014년

# %%
import pandas as pd
data14_b1 = pd.read_csv("/content/drive/MyDrive/미세먼지 2001-21/2014년 1분기.csv")
data14_b1['지역']=data14_b1['지역'].str[:2]
data14_b1['측정일시'] = data14_b1['측정일시'].astype(str)

replace_set = {'PM10':data14_b1['PM10'].mean()}
data14_b1.fillna(replace_set, inplace=True)
data14_b1['연도']=data14_b1['측정일시'].str[:4]
data14_b1['월']=data14_b1['측정일시'].str[4:6]

data14_b1=data14_b1[['지역','측정소명','PM10','연도','월']]
data14_b1=data14_b1.groupby(by=['지역','측정소명','연도','월'], as_index=False).mean()

# %%
import pandas as pd
data14_b2 = pd.read_csv("/content/drive/MyDrive/미세먼지 2001-21/2014년 2분기.csv")
data14_b2['지역']=data14_b2['지역'].str[:2]
data14_b2['측정일시'] = data14_b2['측정일시'].astype(str)

replace_set = {'PM10':data14_b2['PM10'].mean()}
data14_b2.fillna(replace_set, inplace=True)
data14_b2['연도']=data14_b2['측정일시'].str[:4]
data14_b2['월']=data14_b2['측정일시'].str[4:6]

data14_b2=data14_b2[['지역','측정소명','PM10','연도','월']]
data14_b2=data14_b2.groupby(by=['지역','측정소명','연도','월'], as_index=False).mean()

# %%
import pandas as pd
data14_b3 = pd.read_csv("/content/drive/MyDrive/미세먼지 2001-21/2014년 3분기.csv")
data14_b3['지역']=data14_b3['지역'].str[:2]
data14_b3['측정일시'] = data14_b3['측정일시'].astype(str)

replace_set = {'PM10':data14_b3['PM10'].mean()}
data14_b3.fillna(replace_set, inplace=True)
data14_b3['연도']=data14_b3['측정일시'].str[:4]
data14_b3['월']=data14_b3['측정일시'].str[4:6]

data14_b3=data14_b3[['지역','측정소명','PM10','연도','월']]
data14_b3=data14_b3.groupby(by=['지역','측정소명','연도','월'], as_index=False).mean()

# %%
import pandas as pd
data14_b4 = pd.read_csv("/content/drive/MyDrive/미세먼지 2001-21/2014년 4분기.csv")
data14_b4['지역']=data14_b4['지역'].str[:2]
data14_b4['측정일시'] = data14_b4['측정일시'].astype(str)

replace_set = {'PM10':data14_b4['PM10'].mean()}
data14_b4.fillna(replace_set, inplace=True)
data14_b4['연도']=data14_b4['측정일시'].str[:4]
data14_b4['월']=data14_b4['측정일시'].str[4:6]

data14_b4=data14_b4[['지역','측정소명','PM10','연도','월']]
data14_b4=data14_b4.groupby(by=['지역','측정소명','연도','월'], as_index=False).mean()

# %% [markdown]
# ### 2013년

# %%
import pandas as pd
data13_b1 = pd.read_excel("/content/drive/MyDrive/미세먼지 2001-21/2013년01분기.xlsx")
data13_b1['지역']=data13_b1['지역'].str[:2]
data13_b1['측정일시'] = data13_b1['측정일시'].astype(str)

replace_set = {'PM10':data13_b1['PM10'].mean()}
data13_b1.fillna(replace_set, inplace=True)

data13_b1['연도']=data13_b1['측정일시'].str[:4]
data13_b1['월']=data13_b1['측정일시'].str[4:6]

data13_b1=data13_b1[['지역','측정소명','PM10','연도','월']]
data13_b1=data13_b1.groupby(by=['지역','측정소명','연도','월'], as_index=False).mean()

# %%
import pandas as pd
data13_b2 = pd.read_excel("/content/drive/MyDrive/미세먼지 2001-21/2013년02분기.xlsx")
data13_b2['지역']=data13_b2['지역'].str[:2]
data13_b2['측정일시'] = data13_b2['측정일시'].astype(str)

replace_set = {'PM10':data13_b2['PM10'].mean()}
data13_b2.fillna(replace_set, inplace=True)

data13_b2['연도']=data13_b2['측정일시'].str[:4]
data13_b2['월']=data13_b2['측정일시'].str[4:6]

data13_b2=data13_b2[['지역','측정소명','PM10','연도','월']]
data13_b2=data13_b2.groupby(by=['지역','측정소명','연도','월'], as_index=False).mean()

# %%
import pandas as pd
data13_b3 = pd.read_excel("/content/drive/MyDrive/미세먼지 2001-21/2013년03분기.xlsx")
data13_b3['지역']=data13_b3['지역'].str[:2]
data13_b3['측정일시'] = data13_b3['측정일시'].astype(str)

replace_set = {'PM10':data13_b3['PM10'].mean()}
data13_b3.fillna(replace_set, inplace=True)

data13_b3['연도']=data13_b3['측정일시'].str[:4]
data13_b3['월']=data13_b3['측정일시'].str[4:6]

data13_b3=data13_b3[['지역','측정소명','PM10','연도','월']]
data13_b3=data13_b3.groupby(by=['지역','측정소명','연도','월'], as_index=False).mean()

# %%
import pandas as pd
data13_b4 = pd.read_excel("/content/drive/MyDrive/미세먼지 2001-21/2013년04분기.xlsx")
data13_b4['지역']=data13_b4['지역'].str[:2]
data13_b4['측정일시'] = data13_b4['측정일시'].astype(str)

replace_set = {'PM10':data13_b4['PM10'].mean()}
data13_b4.fillna(replace_set, inplace=True)

data13_b4['연도']=data13_b4['측정일시'].str[:4]
data13_b4['월']=data13_b4['측정일시'].str[4:6]

data13_b4=data13_b4[['지역','측정소명','PM10','연도','월']]
data13_b4=data13_b4.groupby(by=['지역','측정소명','연도','월'], as_index=False).mean()

# %% [markdown]
# ### 엑셀로 저장

# %%
data2021.to_excel('/content/drive/MyDrive/미세먼지 2001-21/data2021.xlsx')

# %%
data2020 = pd.concat([data20_1,data20_2,data20_3,data20_4,data20_5,data20_6,data20_7,data20_8,data20_9,data20_10,data20_11,data20_12],ignore_index=True)
data2020

# %%
data2020.to_excel('/content/drive/MyDrive/미세먼지 2001-21/data2020.xlsx')

# %%
data2019 = pd.concat([data19_1,data19_2,data19_3,data19_4,data19_5,data19_6,data19_7,data19_8,data19_9,data19_10,data19_11,data19_12],ignore_index=True)
data2019

# %%
data2019.to_excel('/content/drive/MyDrive/미세먼지 2001-21/data2019.xlsx')

# %%
data2018 = pd.concat([data18_b1,data18_b2,data18_b3,data18_b4],ignore_index=True)
data2018

# %%
data2018.to_excel('/content/drive/MyDrive/미세먼지 2001-21/data2018.xlsx')

# %%
data2017 = pd.concat([data17_1,data17_2,data17_3,data17_4,data17_5,data17_6,data17_7,data17_8,data17_9,data17_10,data17_11,data17_12],ignore_index=True)
data2017

# %%
data2017.to_excel('/content/drive/MyDrive/미세먼지 2001-21/data2017.xlsx')

# %%
data2016 = pd.concat([data16_b1,data16_b2,data16_b3,data16_b4],ignore_index=True)
data2016

# %%
data2016.to_excel('/content/drive/MyDrive/미세먼지 2001-21/data2016.xlsx')

# %%
data2015 = pd.concat([data15_b1,data15_b2,data15_b3,data15_b4],ignore_index=True)

# %%
data2015.to_excel('/content/drive/MyDrive/미세먼지 2001-21/data2015.xlsx')

# %%
data2014 = pd.concat([data14_b1,data14_b2,data14_b3,data14_b4],ignore_index=True)

# %%
data2014.to_excel('/content/drive/MyDrive/미세먼지 2001-21/data2014.xlsx')

# %%
data2013 = pd.concat([data13_b1,data13_b2,data13_b3,data13_b4],ignore_index=True)

# %%
data2013.to_excel('/content/drive/MyDrive/미세먼지 2001-21/data2013.xlsx')

# %% [markdown]
# ## 데이터 전처리

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 37 not upgraded.
# Need to get 9,604 kB of archives.
# After this operation, 29.5 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 fonts-nanum all 20170925-1 [9,604 kB]
# Fetched 9,604 kB in 1s (10.2 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# ...

# %%
import matplotlib.font_manager as fm
font_list = [font.name for font in fm.fontManager.ttflist]
font_list
# Out:
# ['STIXNonUnicode',
#  'cmr10',
#  'STIXGeneral',
#  'DejaVu Sans Mono',
#  'DejaVu Serif',
#  'STIXSizeThreeSym',
#  'STIXSizeFourSym',
#  'STIXSizeOneSym',
#  'STIXGeneral',
#  'STIXSizeTwoSym',
#  'DejaVu Sans Mono',
#  'DejaVu Serif',
#  'STIXSizeTwoSym',
#  'STIXSizeFourSym',
#  'DejaVu Sans Mono',
#  'STIXNonUnicode',
#  'DejaVu Serif',
#  'STIXGeneral',
#  'cmex10',
#  'STIXNonUnicode',
#  'DejaVu Serif',
#  'cmss10',
#  'cmtt10',
#  'cmmi10',
#  'STIXSizeOneSym',
#  'DejaVu Sans',
#  'DejaVu Sans',
#  'cmsy10',
#  'STIXGeneral',
#  'DejaVu Sans',
#  'STIXNonUnicode',
#  'DejaVu Sans Mono',
#  'cmb10',
#  'STIXSizeThreeSym',
#  'DejaVu Serif Display',
#  'DejaVu Sans Display',
#  'DejaVu Sans',
#  'STIXSizeFiveSym',
#  'Liberation Mono',
#  'Liberation Sans Narrow',
#  'Liberation Mono',
#  'Liberation Sans Narrow',
#  'Liberation Serif',
#  'Liberation Mono',
#  'Liberation Sans',
#  'Liberation Mono',
#  'Liberation Serif',
#  'Liberation Sans',
#  'Liberation Sans Narrow',
# ...

# %%
import pandas as pd
data2021= pd.read_excel("/content/drive/MyDrive/미세먼지 2001-21/data2021.xlsx")
data2020= pd.read_excel("/content/drive/MyDrive/미세먼지 2001-21/data2020.xlsx")
data2019= pd.read_excel("/content/drive/MyDrive/미세먼지 2001-21/data2019.xlsx")
data2018= pd.read_excel("/content/drive/MyDrive/미세먼지 2001-21/data2018.xlsx")
data2017= pd.read_excel("/content/drive/MyDrive/미세먼지 2001-21/data2017.xlsx")
data2016= pd.read_excel("/content/drive/MyDrive/미세먼지 2001-21/data2016.xlsx")
data2015= pd.read_excel("/content/drive/MyDrive/미세먼지 2001-21/data2015.xlsx")
data2014= pd.read_excel("/content/drive/MyDrive/미세먼지 2001-21/data2014.xlsx")
data2013= pd.read_excel("/content/drive/MyDrive/미세먼지 2001-21/data2013.xlsx")

# %%
data_all = pd.concat([data2021,data2020,data2019,data2018,data2017,data2016],axis=0,ignore_index=True)

# %%
data_all_13 = pd.concat([data2021,data2020,data2019,data2018,data2017,data2016,data2015,data2014,data2013],axis=0,ignore_index=True)

# %%
data_all=data_all.drop(data_all.columns[0],axis=1)

# %%
data_all=data_all[['지역','연도','월','PM10','PM25']]

# %%
data_all_13 = data_all_13[['지역','연도','월','PM10']]

# %%
data_all=data_all.groupby(by=['지역','연도','월'], as_index=False).mean()

# %%
data_all_13=data_all_13.groupby(by=['지역','연도','월'], as_index=False).mean()

# %% [markdown]
# ##데이터 시각화

# %% [markdown]
# ##1. 연도-월별 미세먼지와 초미세먼지 변화
#
# *   미세먼지는 시간이 흐를수록 많아지는 추세인가?
# *   미세먼지가 많아지는 시기(패턴)가 있을까? (ex봄-황사)
# *   미세먼지가 많으면 초미세먼지도 많은가>

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
plt.rc('font', family='NanumGothic')

mpl.rc('axes', unicode_minus=False)

# %%
data_all_month = data_all[['연도','월','PM10','PM25']]

# %%
data_all_month=data_all_month.groupby(by=['연도','월'], as_index=False).mean()

# %%
data_all_month.sort_values(by=['연도', '월'])
# Out:
#       연도   월       PM10       PM25
# 0   2016   1  47.776691  29.889215
# 1   2016   2  46.613986  28.216624
# 2   2016   3  57.335185  30.801235
# 3   2016   4  63.756278  28.703004
# 4   2016   5  52.699701  28.348458
# ..   ...  ..        ...        ...
# 59  2020  12  37.256497  23.426163
# 60  2021   1  38.725888  20.265636
# 61  2021   2  42.428212  24.491096
# 62  2021   3  64.840023  25.997748
# 63  2021   4  40.802049  16.925952
#
# [64 rows x 4 columns]

# %%
data_all_month['연도']=data_all_month['연도'].astype(str)
data_all_month['월']=data_all_month['월'].astype(str)
data_all_month['날짜']=data_all_month['연도']+'-'+data_all_month['월'].apply(str)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.rc('font', family='NanumBarunGothic')

# %%
X = data_all_month['날짜']
Y1 = data_all_month['PM10']
Y2= data_all_month['PM25']

plt.style.use(['fivethirtyeight'])

plt.rc('font', size=20)
plt.figure(figsize=(50,16))
plt.plot(X, Y1,marker='o',label='PM10')
plt.plot(X, Y2,marker='o',label='PM2.5')
plt.tick_params(labelsize=25)
plt.xticks(rotation=90) 
plt.legend(loc='upper left',fontsize=20)

plt.show()

# %% [markdown]
# 연도별

# %%
data_all_2021=data_all[['연도','월','PM10','PM25']]

# %%
data_to_insert = {'연도': 2021, '월': 5}
data_all_2021=data_all_2021.append(data_to_insert, ignore_index=True)
data_to_insert = {'연도': 2021, '월': 6}
data_all_2021=data_all_2021.append(data_to_insert, ignore_index=True)
data_to_insert = {'연도': 2021, '월': 7}
data_all_2021=data_all_2021.append(data_to_insert, ignore_index=True)
data_to_insert = {'연도': 2021, '월': 8}
data_all_2021=data_all_2021.append(data_to_insert, ignore_index=True)
data_to_insert = {'연도': 2021, '월': 9}
data_all_2021=data_all_2021.append(data_to_insert, ignore_index=True)
data_to_insert = {'연도': 2021, '월': 10}
data_all_2021=data_all_2021.append(data_to_insert, ignore_index=True)
data_to_insert = {'연도': 2021, '월': 11}
data_all_2021=data_all_2021.append(data_to_insert, ignore_index=True)
data_to_insert = {'연도': 2021, '월': 12}
data_all_2021=data_all_2021.append(data_to_insert, ignore_index=True)
replace_set = {'PM10':data_all_2021['PM10'].mean()}
data_all_2021.fillna(replace_set, inplace=True)
replace_set = {'PM25':data_all_2021['PM25'].mean()}
data_all_2021.fillna(replace_set, inplace=True)

# %%
data_all_2021=data_all[['연도','PM10','PM25']]

# %%
data_all_2021=data_all_2021.groupby(by=['연도'], as_index=False).mean()

# %%
  import matplotlib.pyplot as plt
  import seaborn as sns

  plt.rc('font', family='NanumBarunGothic')

# %%
data_all_2021.plot(x="연도", y=["PM10", "PM25"], kind="bar",figsize=(10,8))
plt.style.use('ggplot')
plt.xticks(rotation=0) 
plt.ylim([0, 60]) 
plt.legend()
plt.show()
# Out:
# findfont: Font family ['NanumBarunGothic'] not found. Falling back to DejaVu Sans.
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50672 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# findfont: Font family ['NanumBarunGothic'] not found. Falling back to DejaVu Sans.
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 50672 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
data_all_2021m=data_all[['월','PM10','PM25']]
data_all_2021m=data_all_2021m.groupby(by=['월'], as_index=False).mean()

# %%
import matplotlib.pyplot as plt

plt.rc('font', family='NanumBarunGothic')
plt.style.use('ggplot')
data_all_2021m.plot(x="월", y=["PM10", "PM25"], kind="bar",figsize=(10,7))
plt.xticks(rotation=0) 
plt.ylim([0, 60]) 
plt.legend()
plt.show()

# %% [markdown]
# ##2. (초)미세먼지가 가장 많은 지역은 어디인가?

# %%
data_all_region = data_all[['지역','PM10','PM25']]
data_all_region = data_all_region.groupby(by=['지역'], as_index=False).mean()
data_all_region=data_all_region.sort_values(by='PM10',ascending=False)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.rc('font', family='NanumBarunGothic')

plt.style.use('seaborn-poster')
plt.figure(figsize=(8,10))
sns.scatterplot(x='PM10', y='지역', data=data_all_region)
sns.set(font_scale=2)
plt.show()

# %%
data_all_region=data_all_region.sort_values(by='PM25',ascending=False)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.rc('font', family='NanumBarunGothic')
plt.style.use('seaborn-poster')
plt.figure(figsize=(8,10))
sns.scatterplot(x='PM25', y='지역', data=data_all_region)
sns.set(font_scale=2)

plt.show()

# %% [markdown]
# ##3. 중국과 가까울수록 미세먼지가 많을까?

# %%
data_all_china = data_all_13.groupby(by=['지역','연도'], as_index=False).mean()
data_all_china=data_all_china[['지역','PM10']]

# %%
import pandas as pd
from pandas import Series, DataFrame
China = DataFrame([["서울",951.15],["경남",1149.08],["전북",1051.70],["부산",1229.04],
                 ["세종",1032.53],["인천",930.71],["경북","1155.83"],["제주","1149.36"],["경기",963.77],
                 ["광주",1060.98],["충북",1042.36],["울산","1231.09"],["전남","1088.49"],["대구",1156.89],
                 ["충남",981.52],["대전",1036.79],["강원","1043.56"]], columns = ["지역","km_to_China"])

# %%
data_all_china=pd.merge(left = China , right = data_all_china, how = "inner", on = "지역")

# %%
replace_set = {'PM10':data_all_china['PM10'].mean()}
data_all_china.fillna(replace_set, inplace=True)

# %%
data_all_china['km_to_China']=pd.to_numeric(data_all_china['km_to_China'])
data_all_china=data_all_china.sort_values(by='km_to_China',ascending=True)

# %%
data_all_china = data_all_china.groupby(by=['지역'], as_index=False).mean()

# %%
data_all_china=data_all_china.sort_values(by='km_to_China',ascending=True)

# %%
data_all_china
# Out:
#     지역  km_to_China       PM10
# 11  인천       930.71  41.842117
# 8   서울       951.15  43.133568
# 1   경기       963.77  45.741991
# 15  충남       981.52  40.140634
# 9   세종      1032.53  44.046458
# 6   대전      1036.79  41.911378
# 16  충북      1042.36  43.096952
# 0   강원      1043.56  38.925113
# 13  전북      1051.70  40.687035
# 4   광주      1060.98  41.466706
# 12  전남      1088.49  33.483857
# 2   경남      1149.08  38.669031
# 14  제주      1149.36  37.753255
# 3   경북      1155.83  33.031386
# 5   대구      1156.89  41.788430
# 7   부산      1229.04  39.738161
# 10  울산      1231.09  39.479390

# %%
sns.barplot(x=data_all_china.지역, y=data_all_china.PM10, color="orange")
plt.ylim([0, 60]) 
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
plt.style.use(['bmh'])
plt.scatter(data_all_china.km_to_China,data_all_china.PM10)
plt.xlabel('km')
plt.ylabel('PM10')
plt.show()
